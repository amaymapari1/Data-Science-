# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['age'].fillna(df['age'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
dir(sns)
# Out:
# ['FacetGrid',
#  'JointGrid',
#  'PairGrid',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_compat',
#  '_core',
#  '_decorators',
#  '_docstrings',
#  '_oldcore',
#  '_orig_rc_params',
#  '_statistics',
#  '_stats',
#  'algorithms',
#  'axes_style',
#  'axisgrid',
#  'barplot',
#  'blend_palette',
#  'boxenplot',
#  'boxplot',
#  'categorical',
#  'catplot',
#  'choose_colorbrewer_palette',
#  'choose_cubehelix_palette',
#  'choose_dark_palette',
#  'choose_diverging_palette',
#  'choose_light_palette',
#  'clustermap',
#  'cm',
#  'color_palette',
#  'colors',
#  'countplot',
#  'crayon_palette',
#  'crayons',
#  'cubehelix_palette',
#  'dark_palette',
#  'desaturate',
#  'despine',
#  'displot',
#  'distplot',
#  'distributions',
#  'diverging_palette',
#  'dogplot',
#  'ecdfplot',
#  'external',
#  'get_data_home',
#  'get_dataset_names',
#  'heatmap',
# ...

# %%
sns.histplot(data=df['fare'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(data=df['fare'],bins=1000)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(data=df,x=df['fare'],bins=5)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.catplot(x='sex',y='age',hue='survived',data=df)

# %%
sns.displot(data=df,x=df['fare'],kde=True)#kde is used for line

# %%
sns.displot(data=df,x=df['fare'],kde=False,bins=10)

# %%
sns.jointplot(data=df,x=df['age'],y=df['fare'])

# %%
sns.jointplot(data=df,x=df['age'],y=df['fare'],kind='hex')

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df.select_dtypes(include='number').columns.size
# Out:
# 6

# %%
df.select_dtypes(include='bool').columns.size
# Out:
# 2

# %%
sns.pairplot(df)# possible all combinations of number + bool dtypes(6+2) =8 (8*8=64)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
sns.pairplot(data=df,hue='sex')

# %%
sns.barplot(data=df,x='sex',y='age')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(data=df,x='sex',y='age',hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.countplot(data=df,x='survived')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data=df,x='survived',hue='sex')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.boxplot(data=df,x='age')
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(data=df,x='age',y='sex')
# Out:
# <Axes: xlabel='age', ylabel='sex'>

# %%
sns.boxplot(data=df,x='age',y='sex',hue='survived')
# Out:
# <Axes: xlabel='age', ylabel='sex'>

# %%
sns.violinplot(data=df,x='sex',y='age')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(data=df,x='sex',y='age',hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.scatterplot(data=df,x='sex',y='age')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.scatterplot(data=df,x='sex',y='age',hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
fig,axes=plt.subplots(2,2)
print(fig)
print(axes)
sns.boxplot(data=df,x='survived',y='age',ax=axes[0,0])
sns.boxplot(data=df,x='survived',y='fare',ax=axes[0,1])
sns.boxplot(data=df,x='survived',y='parch',ax=axes[1,0])
sns.boxplot(data=df,x='survived',y='pclass',ax=axes[1,1])
# Out:
# Figure(640x480)
# [[<Axes: > <Axes: >]
#  [<Axes: > <Axes: >]]
# <Axes: xlabel='survived', ylabel='pclass'>
