# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize 
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer,WordNetLemmatizer
from nltk import pos_tag
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
with open('./amay.txt') as f:
    para=f.read()
    para=para.lower()

# %%
para
# Out:
# "'bali is predominantly a hindu country. bali is known for its elaborate, traditional dancing. the dancing is inspired by its hindi beliefs. most of the dancing portrays tales of good versus evil. to watch the dancing is a breathtaking experience. lombok has some impressive points of interest â€“ the majestic gunung rinjani is an active volcano. it is the second highest peak in indonesia. art is a balinese passion. batik paintings and carved statues make popular souvenirs. artists can be seen whittling and painting on the streets, particularly in ubud. it is easy to appreciate each island as an attractive tourist destination. majestic scenery; rich culture; white sands and warm, azure waters draw visitors like magnets every year. snorkelling and diving around the nearby gili islands is magnificent. marine fish, starfish, turtles and coral reef are present in abundance. bali and lombok are part of the indonesian archipelago. bali has some spectacular temples. the most significant is the mother temple, besakih. the inhabitants of lombok are mostly muslim with a hindu minority. lombok remains the most understated of the two islands. lombok has several temples worthy of a visit, though they are less prolific. bali and lombok are neighbouring islands. '"

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Amay\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
sentence_token=sent_tokenize(para)

# %%
sentence_token
# Out:
# ["'bali is predominantly a hindu country.",
#  'bali is known for its elaborate, traditional dancing.',
#  'the dancing is inspired by its hindi beliefs.',
#  'most of the dancing portrays tales of good versus evil.',
#  'to watch the dancing is a breathtaking experience.',
#  'lombok has some impressive points of interest â€“ the majestic gunung rinjani is an active volcano.',
#  'it is the second highest peak in indonesia.',
#  'art is a balinese passion.',
#  'batik paintings and carved statues make popular souvenirs.',
#  'artists can be seen whittling and painting on the streets, particularly in ubud.',
#  'it is easy to appreciate each island as an attractive tourist destination.',
#  'majestic scenery; rich culture; white sands and warm, azure waters draw visitors like magnets every year.',
#  'snorkelling and diving around the nearby gili islands is magnificent.',
#  'marine fish, starfish, turtles and coral reef are present in abundance.',
#  'bali and lombok are part of the indonesian archipelago.',
#  'bali has some spectacular temples.',
#  'the most significant is the mother temple, besakih.',
#  'the inhabitants of lombok are mostly muslim with a hindu minority.',
#  'lombok remains the most understated of the two islands.',
#  'lombok has several temples worthy of a visit, though they are less prolific.',
#  "bali and lombok are neighbouring islands. '"]

# %%
len(sentence_token)
# Out:
# 21

# %%
word_token=word_tokenize(para)

# %%
word_token
# Out:
# ["'bali",
#  'is',
#  'predominantly',
#  'a',
#  'hindu',
#  'country',
#  '.',
#  'bali',
#  'is',
#  'known',
#  'for',
#  'its',
#  'elaborate',
#  ',',
#  'traditional',
#  'dancing',
#  '.',
#  'the',
#  'dancing',
#  'is',
#  'inspired',
#  'by',
#  'its',
#  'hindi',
#  'beliefs',
#  '.',
#  'most',
#  'of',
#  'the',
#  'dancing',
#  'portrays',
#  'tales',
#  'of',
#  'good',
#  'versus',
#  'evil',
#  '.',
#  'to',
#  'watch',
#  'the',
#  'dancing',
#  'is',
#  'a',
#  'breathtaking',
#  'experience',
#  '.',
#  'lombok',
#  'has',
#  'some',
#  'impressive',
#  'points',
#  'of',
#  'interest',
#  'â€',
#  '“',
#  'the',
#  'majestic',
#  'gunung',
#  'rinjani',
#  'is',
#  'an',
#  'active',
#  'volcano',
#  '.',
#  'it',
#  'is',
#  'the',
#  'second',
#  'highest',
#  'peak',
#  'in',
#  'indonesia',
#  '.',
#  'art',
#  'is',
#  'a',
#  'balinese',
#  'passion',
#  '.',
#  'batik',
#  'paintings',
#  'and',
#  'carved',
#  'statues',
#  'make',
#  'popular',
#  'souvenirs',
#  '.',
#  'artists',
#  'can',
#  'be',
#  'seen',
#  'whittling',
#  'and',
#  'painting',
#  'on',
#  'the',
#  'streets',
#  ',',
#  'particularly',
#  'in',
#  'ubud',
#  '.',
#  'it',
#  'is',
#  'easy',
#  'to',
#  'appreciate',
#  'each',
#  'island',
#  'as',
#  'an',
#  'attractive',
#  'tourist',
#  'destination',
#  '.',
#  'majestic',
#  'scenery',
#  ';',
#  'rich',
#  'culture',
#  ';',
#  'white',
#  'sands',
#  'and',
#  'warm',
#  ',',
#  'azure',
#  'waters',
#  'draw',
#  'visitors',
#  'like',
#  'magnets',
#  'every',
#  'year',
#  '.',
#  'snorkelling',
#  'and',
#  'diving',
#  'around',
#  'the',
#  'nearby',
#  'gili',
#  'islands',
#  'is',
#  'magnificent',
#  '.',
#  'marine',
#  'fish',
#  ',',
#  'starfish',
#  ',',
#  'turtles',
#  'and',
#  'coral',
#  'reef',
#  'are',
#  'present',
#  'in',
#  'abundance',
#  '.',
#  'bali',
#  'and',
#  'lombok',
#  'are',
#  'part',
#  'of',
#  'the',
#  'indonesian',
#  'archipelago',
#  '.',
#  'bali',
#  'has',
#  'some',
#  'spectacular',
#  'temples',
#  '.',
#  'the',
#  'most',
#  'significant',
#  'is',
#  'the',
#  'mother',
#  'temple',
#  ',',
#  'besakih',
#  '.',
#  'the',
#  'inhabitants',
#  'of',
#  'lombok',
#  'are',
#  'mostly',
#  'muslim',
#  'with',
#  'a',
#  'hindu',
#  'minority',
#  '.',
#  'lombok',
#  'remains',
#  'the',
#  'most',
#  'understated',
#  'of',
#  'the',
#  'two',
#  'islands',
#  '.',
#  'lombok',
#  'has',
#  'several',
#  'temples',
#  'worthy',
#  'of',
#  'a',
#  'visit',
#  ',',
#  'though',
#  'they',
#  'are',
#  'less',
#  'prolific',
#  '.',
#  'bali',
#  'and',
#  'lombok',
#  'are',
#  'neighbouring',
#  'islands',
#  '.',
#  "'"]

# %%
len(word_token)
# Out:
# 232

# %%
word_token[0]
# Out:
# "'bali"

# %%
type(word_token)
# Out:
# list

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Amay\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
tagged=nltk.pos_tag(word_token)

# %%
tagged
# Out:
# [("'bali", 'NN'),
#  ('is', 'VBZ'),
#  ('predominantly', 'RB'),
#  ('a', 'DT'),
#  ('hindu', 'JJ'),
#  ('country', 'NN'),
#  ('.', '.'),
#  ('bali', 'NN'),
#  ('is', 'VBZ'),
#  ('known', 'VBN'),
#  ('for', 'IN'),
#  ('its', 'PRP$'),
#  ('elaborate', 'NN'),
#  (',', ','),
#  ('traditional', 'JJ'),
#  ('dancing', 'NN'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('dancing', 'NN'),
#  ('is', 'VBZ'),
#  ('inspired', 'VBN'),
#  ('by', 'IN'),
#  ('its', 'PRP$'),
#  ('hindi', 'NN'),
#  ('beliefs', 'NN'),
#  ('.', '.'),
#  ('most', 'JJS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('dancing', 'NN'),
#  ('portrays', 'VBZ'),
#  ('tales', 'NNS'),
#  ('of', 'IN'),
#  ('good', 'JJ'),
#  ('versus', 'NN'),
#  ('evil', 'NN'),
#  ('.', '.'),
#  ('to', 'TO'),
#  ('watch', 'VB'),
#  ('the', 'DT'),
#  ('dancing', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('breathtaking', 'JJ'),
#  ('experience', 'NN'),
#  ('.', '.'),
#  ('lombok', 'NN'),
#  ('has', 'VBZ'),
#  ('some', 'DT'),
#  ('impressive', 'JJ'),
#  ('points', 'NNS'),
#  ('of', 'IN'),
#  ('interest', 'NN'),
#  ('â€', 'NN'),
#  ('“', 'VBD'),
#  ('the', 'DT'),
#  ('majestic', 'JJ'),
#  ('gunung', 'NN'),
#  ('rinjani', 'NN'),
#  ('is', 'VBZ'),
#  ('an', 'DT'),
#  ('active', 'JJ'),
#  ('volcano', 'NN'),
#  ('.', '.'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('second', 'JJ'),
#  ('highest', 'JJS'),
#  ('peak', 'NN'),
#  ('in', 'IN'),
#  ('indonesia', 'NN'),
#  ('.', '.'),
#  ('art', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('balinese', 'JJ'),
#  ('passion', 'NN'),
#  ('.', '.'),
#  ('batik', 'JJ'),
#  ('paintings', 'NNS'),
#  ('and', 'CC'),
#  ('carved', 'VBD'),
#  ('statues', 'NNS'),
#  ('make', 'VBP'),
#  ('popular', 'JJ'),
#  ('souvenirs', 'NNS'),
#  ('.', '.'),
#  ('artists', 'NNS'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('seen', 'VBN'),
#  ('whittling', 'VBG'),
#  ('and', 'CC'),
#  ('painting', 'VBG'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('streets', 'NNS'),
#  (',', ','),
#  ('particularly', 'RB'),
#  ('in', 'IN'),
#  ('ubud', 'NN'),
#  ('.', '.'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('easy', 'JJ'),
#  ('to', 'TO'),
#  ('appreciate', 'VB'),
#  ('each', 'DT'),
#  ('island', 'NN'),
#  ('as', 'IN'),
#  ('an', 'DT'),
#  ('attractive', 'JJ'),
#  ('tourist', 'NN'),
#  ('destination', 'NN'),
#  ('.', '.'),
#  ('majestic', 'JJ'),
#  ('scenery', 'NN'),
#  (';', ':'),
#  ('rich', 'JJ'),
#  ('culture', 'NN'),
#  (';', ':'),
#  ('white', 'JJ'),
#  ('sands', 'NNS'),
#  ('and', 'CC'),
#  ('warm', 'NN'),
#  (',', ','),
#  ('azure', 'NN'),
#  ('waters', 'NNS'),
#  ('draw', 'VBP'),
#  ('visitors', 'NNS'),
#  ('like', 'IN'),
#  ('magnets', 'NNS'),
#  ('every', 'DT'),
#  ('year', 'NN'),
#  ('.', '.'),
#  ('snorkelling', 'NN'),
#  ('and', 'CC'),
#  ('diving', 'VBG'),
#  ('around', 'IN'),
#  ('the', 'DT'),
#  ('nearby', 'JJ'),
#  ('gili', 'NN'),
#  ('islands', 'NNS'),
#  ('is', 'VBZ'),
#  ('magnificent', 'JJ'),
#  ('.', '.'),
#  ('marine', 'JJ'),
#  ('fish', 'NN'),
#  (',', ','),
#  ('starfish', 'JJ'),
#  (',', ','),
#  ('turtles', 'NNS'),
#  ('and', 'CC'),
#  ('coral', 'JJ'),
#  ('reef', 'NN'),
#  ('are', 'VBP'),
#  ('present', 'JJ'),
#  ('in', 'IN'),
#  ('abundance', 'NN'),
#  ('.', '.'),
#  ('bali', 'NN'),
#  ('and', 'CC'),
#  ('lombok', 'NNS'),
#  ('are', 'VBP'),
#  ('part', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('indonesian', 'JJ'),
#  ('archipelago', 'NN'),
#  ('.', '.'),
#  ('bali', 'NN'),
#  ('has', 'VBZ'),
#  ('some', 'DT'),
#  ('spectacular', 'JJ'),
#  ('temples', 'NNS'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('significant', 'JJ'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('mother', 'NN'),
#  ('temple', 'NN'),
#  (',', ','),
#  ('besakih', 'NN'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('inhabitants', 'NNS'),
#  ('of', 'IN'),
#  ('lombok', 'NNS'),
#  ('are', 'VBP'),
#  ('mostly', 'RB'),
#  ('muslim', 'JJ'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('hindu', 'JJ'),
#  ('minority', 'NN'),
#  ('.', '.'),
#  ('lombok', 'NN'),
#  ('remains', 'VBZ'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('understated', 'JJ'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('two', 'CD'),
#  ('islands', 'NNS'),
#  ('.', '.'),
#  ('lombok', 'NN'),
#  ('has', 'VBZ'),
#  ('several', 'JJ'),
#  ('temples', 'NNS'),
#  ('worthy', 'NNS'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('visit', 'NN'),
#  (',', ','),
#  ('though', 'IN'),
#  ('they', 'PRP'),
#  ('are', 'VBP'),
#  ('less', 'RBR'),
#  ('prolific', 'JJ'),
#  ('.', '.'),
#  ('bali', 'NN'),
#  ('and', 'CC'),
#  ('lombok', 'NN'),
#  ('are', 'VBP'),
#  ('neighbouring', 'VBG'),
#  ('islands', 'NNS'),
#  ('.', '.'),
#  ("'", "''")]

# %%
type(tagged[0])
# Out:
# tuple

# %%
 nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Amay\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stop_words=stopwords.words('english')

# %%
set(stop_words)
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
filtered_tokens=[]
for token in word_token:
    if token not in stop_words:
        filtered_tokens.append(token)

# %%
filtered_tokens
# Out:
# ["'bali",
#  'predominantly',
#  'hindu',
#  'country',
#  '.',
#  'bali',
#  'known',
#  'elaborate',
#  ',',
#  'traditional',
#  'dancing',
#  '.',
#  'dancing',
#  'inspired',
#  'hindi',
#  'beliefs',
#  '.',
#  'dancing',
#  'portrays',
#  'tales',
#  'good',
#  'versus',
#  'evil',
#  '.',
#  'watch',
#  'dancing',
#  'breathtaking',
#  'experience',
#  '.',
#  'lombok',
#  'impressive',
#  'points',
#  'interest',
#  'â€',
#  '“',
#  'majestic',
#  'gunung',
#  'rinjani',
#  'active',
#  'volcano',
#  '.',
#  'second',
#  'highest',
#  'peak',
#  'indonesia',
#  '.',
#  'art',
#  'balinese',
#  'passion',
#  '.',
#  'batik',
#  'paintings',
#  'carved',
#  'statues',
#  'make',
#  'popular',
#  'souvenirs',
#  '.',
#  'artists',
#  'seen',
#  'whittling',
#  'painting',
#  'streets',
#  ',',
#  'particularly',
#  'ubud',
#  '.',
#  'easy',
#  'appreciate',
#  'island',
#  'attractive',
#  'tourist',
#  'destination',
#  '.',
#  'majestic',
#  'scenery',
#  ';',
#  'rich',
#  'culture',
#  ';',
#  'white',
#  'sands',
#  'warm',
#  ',',
#  'azure',
#  'waters',
#  'draw',
#  'visitors',
#  'like',
#  'magnets',
#  'every',
#  'year',
#  '.',
#  'snorkelling',
#  'diving',
#  'around',
#  'nearby',
#  'gili',
#  'islands',
#  'magnificent',
#  '.',
#  'marine',
#  'fish',
#  ',',
#  'starfish',
#  ',',
#  'turtles',
#  'coral',
#  'reef',
#  'present',
#  'abundance',
#  '.',
#  'bali',
#  'lombok',
#  'part',
#  'indonesian',
#  'archipelago',
#  '.',
#  'bali',
#  'spectacular',
#  'temples',
#  '.',
#  'significant',
#  'mother',
#  'temple',
#  ',',
#  'besakih',
#  '.',
#  'inhabitants',
#  'lombok',
#  'mostly',
#  'muslim',
#  'hindu',
#  'minority',
#  '.',
#  'lombok',
#  'remains',
#  'understated',
#  'two',
#  'islands',
#  '.',
#  'lombok',
#  'several',
#  'temples',
#  'worthy',
#  'visit',
#  ',',
#  'though',
#  'less',
#  'prolific',
#  '.',
#  'bali',
#  'lombok',
#  'neighbouring',
#  'islands',
#  '.',
#  "'"]

# %%
stemmer=PorterStemmer()
stemmed_tokens=[stemmer.stem(token) for token in filtered_tokens]

# %%
stemmed_tokens
# Out:
# ["'bali",
#  'predominantli',
#  'hindu',
#  'countri',
#  '.',
#  'bali',
#  'known',
#  'elabor',
#  ',',
#  'tradit',
#  'danc',
#  '.',
#  'danc',
#  'inspir',
#  'hindi',
#  'belief',
#  '.',
#  'danc',
#  'portray',
#  'tale',
#  'good',
#  'versu',
#  'evil',
#  '.',
#  'watch',
#  'danc',
#  'breathtak',
#  'experi',
#  '.',
#  'lombok',
#  'impress',
#  'point',
#  'interest',
#  'â€',
#  '“',
#  'majest',
#  'gunung',
#  'rinjani',
#  'activ',
#  'volcano',
#  '.',
#  'second',
#  'highest',
#  'peak',
#  'indonesia',
#  '.',
#  'art',
#  'balines',
#  'passion',
#  '.',
#  'batik',
#  'paint',
#  'carv',
#  'statu',
#  'make',
#  'popular',
#  'souvenir',
#  '.',
#  'artist',
#  'seen',
#  'whittl',
#  'paint',
#  'street',
#  ',',
#  'particularli',
#  'ubud',
#  '.',
#  'easi',
#  'appreci',
#  'island',
#  'attract',
#  'tourist',
#  'destin',
#  '.',
#  'majest',
#  'sceneri',
#  ';',
#  'rich',
#  'cultur',
#  ';',
#  'white',
#  'sand',
#  'warm',
#  ',',
#  'azur',
#  'water',
#  'draw',
#  'visitor',
#  'like',
#  'magnet',
#  'everi',
#  'year',
#  '.',
#  'snorkel',
#  'dive',
#  'around',
#  'nearbi',
#  'gili',
#  'island',
#  'magnific',
#  '.',
#  'marin',
#  'fish',
#  ',',
#  'starfish',
#  ',',
#  'turtl',
#  'coral',
#  'reef',
#  'present',
#  'abund',
#  '.',
#  'bali',
#  'lombok',
#  'part',
#  'indonesian',
#  'archipelago',
#  '.',
#  'bali',
#  'spectacular',
#  'templ',
#  '.',
#  'signific',
#  'mother',
#  'templ',
#  ',',
#  'besakih',
#  '.',
#  'inhabit',
#  'lombok',
#  'mostli',
#  'muslim',
#  'hindu',
#  'minor',
#  '.',
#  'lombok',
#  'remain',
#  'underst',
#  'two',
#  'island',
#  '.',
#  'lombok',
#  'sever',
#  'templ',
#  'worthi',
#  'visit',
#  ',',
#  'though',
#  'less',
#  'prolif',
#  '.',
#  'bali',
#  'lombok',
#  'neighbour',
#  'island',
#  '.',
#  "'"]

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Amay\AppData\Roaming\nltk_data...
# True

# %%
lemmatizer=WordNetLemmatizer()
lemmatized_tokens=[lemmatizer.lemmatize(token) for token in filtered_tokens]

# %%
lemmatized_tokens
# Out:
# ["'bali",
#  'predominantly',
#  'hindu',
#  'country',
#  '.',
#  'bali',
#  'known',
#  'elaborate',
#  ',',
#  'traditional',
#  'dancing',
#  '.',
#  'dancing',
#  'inspired',
#  'hindi',
#  'belief',
#  '.',
#  'dancing',
#  'portrays',
#  'tale',
#  'good',
#  'versus',
#  'evil',
#  '.',
#  'watch',
#  'dancing',
#  'breathtaking',
#  'experience',
#  '.',
#  'lombok',
#  'impressive',
#  'point',
#  'interest',
#  'â€',
#  '“',
#  'majestic',
#  'gunung',
#  'rinjani',
#  'active',
#  'volcano',
#  '.',
#  'second',
#  'highest',
#  'peak',
#  'indonesia',
#  '.',
#  'art',
#  'balinese',
#  'passion',
#  '.',
#  'batik',
#  'painting',
#  'carved',
#  'statue',
#  'make',
#  'popular',
#  'souvenir',
#  '.',
#  'artist',
#  'seen',
#  'whittling',
#  'painting',
#  'street',
#  ',',
#  'particularly',
#  'ubud',
#  '.',
#  'easy',
#  'appreciate',
#  'island',
#  'attractive',
#  'tourist',
#  'destination',
#  '.',
#  'majestic',
#  'scenery',
#  ';',
#  'rich',
#  'culture',
#  ';',
#  'white',
#  'sand',
#  'warm',
#  ',',
#  'azure',
#  'water',
#  'draw',
#  'visitor',
#  'like',
#  'magnet',
#  'every',
#  'year',
#  '.',
#  'snorkelling',
#  'diving',
#  'around',
#  'nearby',
#  'gili',
#  'island',
#  'magnificent',
#  '.',
#  'marine',
#  'fish',
#  ',',
#  'starfish',
#  ',',
#  'turtle',
#  'coral',
#  'reef',
#  'present',
#  'abundance',
#  '.',
#  'bali',
#  'lombok',
#  'part',
#  'indonesian',
#  'archipelago',
#  '.',
#  'bali',
#  'spectacular',
#  'temple',
#  '.',
#  'significant',
#  'mother',
#  'temple',
#  ',',
#  'besakih',
#  '.',
#  'inhabitant',
#  'lombok',
#  'mostly',
#  'muslim',
#  'hindu',
#  'minority',
#  '.',
#  'lombok',
#  'remains',
#  'understated',
#  'two',
#  'island',
#  '.',
#  'lombok',
#  'several',
#  'temple',
#  'worthy',
#  'visit',
#  ',',
#  'though',
#  'le',
#  'prolific',
#  '.',
#  'bali',
#  'lombok',
#  'neighbouring',
#  'island',
#  '.',
#  "'"]

# %%
lemmatized_tokens
# Out:
# ["'bali",
#  'predominantly',
#  'hindu',
#  'country',
#  '.',
#  'bali',
#  'known',
#  'elaborate',
#  ',',
#  'traditional',
#  'dancing',
#  '.',
#  'dancing',
#  'inspired',
#  'hindi',
#  'belief',
#  '.',
#  'dancing',
#  'portrays',
#  'tale',
#  'good',
#  'versus',
#  'evil',
#  '.',
#  'watch',
#  'dancing',
#  'breathtaking',
#  'experience',
#  '.',
#  'lombok',
#  'impressive',
#  'point',
#  'interest',
#  'â€',
#  '“',
#  'majestic',
#  'gunung',
#  'rinjani',
#  'active',
#  'volcano',
#  '.',
#  'second',
#  'highest',
#  'peak',
#  'indonesia',
#  '.',
#  'art',
#  'balinese',
#  'passion',
#  '.',
#  'batik',
#  'painting',
#  'carved',
#  'statue',
#  'make',
#  'popular',
#  'souvenir',
#  '.',
#  'artist',
#  'seen',
#  'whittling',
#  'painting',
#  'street',
#  ',',
#  'particularly',
#  'ubud',
#  '.',
#  'easy',
#  'appreciate',
#  'island',
#  'attractive',
#  'tourist',
#  'destination',
#  '.',
#  'majestic',
#  'scenery',
#  ';',
#  'rich',
#  'culture',
#  ';',
#  'white',
#  'sand',
#  'warm',
#  ',',
#  'azure',
#  'water',
#  'draw',
#  'visitor',
#  'like',
#  'magnet',
#  'every',
#  'year',
#  '.',
#  'snorkelling',
#  'diving',
#  'around',
#  'nearby',
#  'gili',
#  'island',
#  'magnificent',
#  '.',
#  'marine',
#  'fish',
#  ',',
#  'starfish',
#  ',',
#  'turtle',
#  'coral',
#  'reef',
#  'present',
#  'abundance',
#  '.',
#  'bali',
#  'lombok',
#  'part',
#  'indonesian',
#  'archipelago',
#  '.',
#  'bali',
#  'spectacular',
#  'temple',
#  '.',
#  'significant',
#  'mother',
#  'temple',
#  ',',
#  'besakih',
#  '.',
#  'inhabitant',
#  'lombok',
#  'mostly',
#  'muslim',
#  'hindu',
#  'minority',
#  '.',
#  'lombok',
#  'remains',
#  'understated',
#  'two',
#  'island',
#  '.',
#  'lombok',
#  'several',
#  'temple',
#  'worthy',
#  'visit',
#  ',',
#  'though',
#  'le',
#  'prolific',
#  '.',
#  'bali',
#  'lombok',
#  'neighbouring',
#  'island',
#  '.',
#  "'"]

# %%
para_list=[para]

# %%
para_list
# Out:
# ["'bali is predominantly a hindu country. bali is known for its elaborate, traditional dancing. the dancing is inspired by its hindi beliefs. most of the dancing portrays tales of good versus evil. to watch the dancing is a breathtaking experience. lombok has some impressive points of interest â€“ the majestic gunung rinjani is an active volcano. it is the second highest peak in indonesia. art is a balinese passion. batik paintings and carved statues make popular souvenirs. artists can be seen whittling and painting on the streets, particularly in ubud. it is easy to appreciate each island as an attractive tourist destination. majestic scenery; rich culture; white sands and warm, azure waters draw visitors like magnets every year. snorkelling and diving around the nearby gili islands is magnificent. marine fish, starfish, turtles and coral reef are present in abundance. bali and lombok are part of the indonesian archipelago. bali has some spectacular temples. the most significant is the mother temple, besakih. the inhabitants of lombok are mostly muslim with a hindu minority. lombok remains the most understated of the two islands. lombok has several temples worthy of a visit, though they are less prolific. bali and lombok are neighbouring islands. '"]

# %%
vectorizer=TfidfVectorizer()
tfid_matrix=vectorizer.fit_transform(para_list)

# %%
type(tfid_matrix)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
tfid_matrix.toarray()
# Out:
# array([[0.03934447, 0.03934447, 0.07868895, 0.27541132, 0.03934447,
#         0.03934447, 0.19672237, 0.03934447, 0.03934447, 0.03934447,
#         0.03934447, 0.03934447, 0.03934447, 0.19672237, 0.03934447,
#         0.03934447, 0.03934447, 0.03934447, 0.03934447, 0.03934447,
#         0.03934447, 0.03934447, 0.03934447, 0.03934447, 0.03934447,
#         0.03934447, 0.1573779 , 0.03934447, 0.03934447, 0.03934447,
#         0.03934447, 0.03934447, 0.03934447, 0.03934447, 0.03934447,
#         0.03934447, 0.03934447, 0.03934447, 0.03934447, 0.03934447,
#         0.03934447, 0.11803342, 0.03934447, 0.03934447, 0.07868895,
#         0.03934447, 0.11803342, 0.03934447, 0.03934447, 0.03934447,
#         0.03934447, 0.03934447, 0.39344474, 0.03934447, 0.11803342,
#         0.07868895, 0.07868895, 0.03934447, 0.03934447, 0.03934447,
#         0.23606684, 0.03934447, 0.03934447, 0.07868895, 0.03934447,
#         0.03934447, 0.03934447, 0.11803342, 0.03934447, 0.03934447,
#         0.03934447, 0.03934447, 0.03934447, 0.27541132, 0.03934447,
#         0.03934447, 0.03934447, 0.03934447, 0.03934447, 0.03934447,
#         0.03934447, 0.03934447, 0.03934447, 0.03934447, 0.03934447,
#         0.03934447, 0.03934447, 0.03934447, 0.03934447, 0.03934447,
#         0.03934447, 0.03934447, 0.03934447, 0.03934447, 0.03934447,
#         0.03934447, 0.03934447, 0.03934447, 0.07868895, 0.03934447,
#         0.03934447, 0.03934447, 0.03934447, 0.03934447, 0.03934447,
#         0.03934447, 0.07868895, 0.51147816, 0.03934447, 0.03934447,
#         0.07868895, 0.03934447, 0.03934447, 0.03934447, 0.03934447,
#         0.03934447, 0.03934447, 0.03934447, 0.03934447, 0.03934447,
#         0.03934447, 0.03934447, 0.03934447, 0.03934447, 0.03934447,
#         0.03934447, 0.03934447, 0.03934447, 0.03934447]])

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['abundance', 'active', 'an', 'and', 'appreciate', 'archipelago',
#        'are', 'around', 'art', 'artists', 'as', 'attractive', 'azure',
#        'bali', 'balinese', 'batik', 'be', 'beliefs', 'besakih',
#        'breathtaking', 'by', 'can', 'carved', 'coral', 'country',
#        'culture', 'dancing', 'destination', 'diving', 'draw', 'each',
#        'easy', 'elaborate', 'every', 'evil', 'experience', 'fish', 'for',
#        'gili', 'good', 'gunung', 'has', 'highest', 'hindi', 'hindu',
#        'impressive', 'in', 'indonesia', 'indonesian', 'inhabitants',
#        'inspired', 'interest', 'is', 'island', 'islands', 'it', 'its',
#        'known', 'less', 'like', 'lombok', 'magnets', 'magnificent',
#        'majestic', 'make', 'marine', 'minority', 'most', 'mostly',
#        'mother', 'muslim', 'nearby', 'neighbouring', 'of', 'on',
#        'painting', 'paintings', 'part', 'particularly', 'passion', 'peak',
#        'points', 'popular', 'portrays', 'predominantly', 'present',
#        'prolific', 'reef', 'remains', 'rich', 'rinjani', 'sands',
#        'scenery', 'second', 'seen', 'several', 'significant',
#        'snorkelling', 'some', 'souvenirs', 'spectacular', 'starfish',
#        'statues', 'streets', 'tales', 'temple', 'temples', 'the', 'they',
#        'though', 'to', 'tourist', 'traditional', 'turtles', 'two', 'ubud',
#        'understated', 'versus', 'visit', 'visitors', 'volcano', 'warm',
#        'watch', 'waters', 'white', 'whittling', 'with', 'worthy', 'year'],
#       dtype=object)
